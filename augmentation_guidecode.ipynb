# %%
# !pip install datasets
# !pip install transformers
# !pip install konlpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 451 kB 4.6 MB/s
# ...
#      |████████████████████████████████| 182 kB 81.9 MB/s
# ...
#      |████████████████████████████████| 212 kB 88.7 MB/s
# ...
#      |████████████████████████████████| 115 kB 81.9 MB/s
# ...
#      |████████████████████████████████| 127 kB 85.4 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 5.5 MB 4.9 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 73.5 MB/s
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 19.4 MB 4.9 MB/s
# ...
#      |████████████████████████████████| 465 kB 79.8 MB/s
# ...

# %%
from Data_augmentation import data_augmentation

#augmentation 예시
text =  '나는 가끔 눈물을 흘려'

jamo_split = data_augmentation(mode = 'jamo split')
vowel_change = data_augmentation(mode = 'vowel change')
add_dot = data_augmentation(mode = 'add dot')
kor2eng = data_augmentation(mode = 'kor2eng')
yamin = data_augmentation(mode = 'yamin')
eda = data_augmentation(mode='eda')

print("원본 문장 :", text)
print("jamo_split :" ,jamo_split.augmentation(text))
print("vowel_change :", vowel_change.augmentation(text))
print("add_Dot :", add_dot.augmentation(text))
print("kor2eng :", kor2eng.augmentation(text))
print("yamin :", yamin.augmentation(text))
print("eda :",eda.augmentation(text))
# Out:
# 원본 문장 : 나는 가끔 눈물을 흘려
# jamo_split : ㄴㅏ는 ㄱㅏ끔 눈물을 흘ㄹㅕ
# vowel_change : 냐는 갸끔 눈물을 흘러
# add_Dot : 나.는. .가.끔. .눈.물.을. .흘.려.
# kor2eng : Lr는 7r끔 눈물을 흘려
# yamin : 나는 가끔 눈물을 흘려
# eda : 가끔 나는 눈물을 흘려

# %%
root = '/content/drive/MyDrive/우울증챗봇/wellnes_real.csv'  #csv 파일이 들어있는 경로를 입력하면 됩니다.

result = {}

result['jamo_split'] = jamo_split.generation(root,label_column=2, text_column=6)
result['vowel_change'] = vowel_change.generation(root,label_column=2, text_column=6)
result['add_dot'] = (add_dot.generation(root,label_column=2, text_column=6))
result['kor2eng'] = (kor2eng.generation(root,label_column=2, text_column=6))
result['yamin'] = (yamin.generation(root,label_column=2, text_column=6))
result['eda'] = (eda.generation(root,label_column=2, text_column=6))

# %%
bert_result = bert.generation(root,label_column=2, text_column=6)
# Out:
# Downloading:   0%|          | 0.00/425 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/445M [00:00<?, ?B/s]
# Some weights of the model checkpoint at klue/bert-base were not used when initializing BertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Downloading:   0%|          | 0.00/289 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/248k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/495k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/125 [00:00<?, ?B/s]
# ...

# %%
result['bert'] = bert_result

# %%
len(result['eda'])
# Out:
# 19769

# %%
for i in range(len(result['eda'])-len(result['bert'])):
  result['bert'].append('nan')

# %%
import pandas as pd
result_df = pd.DataFrame(result)

# %%
#전체 결과가 포함되어있는 데이터프레임을 csv 파일로 저장합니다.
result_df.to_csv('augmentated_all.csv', index=False, encoding='utf-8-sig')
